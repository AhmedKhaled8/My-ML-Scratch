# %% [markdown]
# # Visualization

# %% [markdown]
# 1. [Why visualization](https://analytiks.co/importance-of-data-visualization/) ?
#
# * Correlations in Relationships: Without data visualization, it is challenging to identify the correlations between the relationship of independent variables. By making sense of those independent variables, we can make better business decisions.
#
# * Trends Over Time: While this seems like an obvious use of data visualization, it is also one of the most valuable applications. It’s impossible to make predictions without having the necessary information from the past and present. Trends over time tell us where we were and where we can potentially go.
#
# * Frequency: Closely related to trends over time is frequency. By examining the rate, or how often, customers purchase and when they buy gives us a better feel for how potential new customers might act and react to different marketing and customer acquisition strategies.
#
# 2. [What are the principles of visualization](https://www.sciencedirect.com/science/article/pii/S2666389920301896) ?
#
# * Diagram First: before you make a visual, prioritize the information you want to share, envision it, and design it.
#
# * Use the Right Software: In other words, it might be unrealistic to expect complex, technical, and effective figures if you are using a simple spreadsheet program or some other software that is not designed to make complex, technical, and effective figures.
#
# * Use an Effective Geometry and Show Data: Geometries are the shapes and features that are often synonymous with a type of figure; for example, the bar geometry creates a bar plot.

# %% [markdown]
# * always use **preceptual uniform sequential colormap** and avoid using **miscellaneous colormaps**.
# * **Diverging** are very good if you are dealing with a scale that the end points are opposite and the middle is neutral.
# * **Sequential** are great for scaling variable on a continous scale.

# %% [markdown]
# ### `matplotlib`

# %% [markdown]
# This is the main plotting library machine learning engineers and data scientists, and this repository :), use for plotting.

# %%
# run this cell to print the version of matplotlib
import matplotlib
matplotlib.__version__
# Out:
# '3.4.3'

# %% [markdown]
# Some additional libraries you should take a look at:
#
# - bokeh (for in-browser plotting)
# - altair
# - yellowbrick (plotting for sklearn)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# In matplolib we have:
#
# - figure: which is the window that holds all plot elements.
# - axes (subplots): which contain most figure elements. They are the drawing areas with coordinate system.
#
# _Each figure has one axes by default but it can have many axes._

# %% [markdown]
# You can create a figure with its axes by many ways:
#
# - Automatically: the library creates the figure when using any plot commands.

# %%
x = np.arange(1, 10)
y = x * 2
plt.plot(x, y)

# %% [markdown]
# - `ax = plt.subplot(n, m , i)`: in a n \* m axes grid. Use the one at index (1-based index) to plot.

# %%
ax11 = plt.subplot(2, 2, 1)
ax12 = plt.subplot(2, 2, 2)
ax13 = plt.subplot(2, 2, 3)
ax14 = plt.subplot(2, 2, 4)

ax11.plot(x, y)

# %% [markdown]
# - `fig, axes = plt.subplots(n, m)`: creates a figrue with an n rows \* m columns grid of axes. `axes[x, y]` to access the axes you want to plot on.

# %%
fig, axes = plt.subplots(2, 2)
ax11, ax12, ax13, ax14 = axes.ravel()

ax12.plot(x, y)

# %% [markdown]
# ***Note:*** We can use the keyword argument `sharey = True` to make the y-axis limits the same for all subplots.

# %% [markdown]
# In `matplotlib`, we can use either of 2 interfaces:
#
# - stateful interface: applies to current figure and axes.

# %%
sin = np.sin(np.linspace(-4, 4, 1000))
plt.subplot(2, 2, 1)
plt.plot(sin) # stateful interface
plt.subplot(2, 2, 2)
plt.plot(sin, c='r') # stateful interface

# %% [markdown]
# - object-oriented interface: explicitly use that object.

# %%
fig, axes = plt.subplots(2, 2)
axes[1, 1].plot(sin, c='b') # object-oriented interface

# %% [markdown]
# Some different between the 2 interfaces:
#
# |      stateful interface       |      Object-oriented interface      |
# | :---------------------------: | :---------------------------------: |
# |         `plt.title()`         |          `ax.set_title()`           |
# |   `plt.xlim()` `plt.ylim()`   |   `ax.set_xlim()` `ax.set_ylim()`   |
# | `plt.xlabel()` `plt.ylabel()` | `ax.set_xlabel()` `ax.set_ylabel()` |
# | `plt.xticks()` `plt.yticks()` | `ax.set_xticks()` `ax.set_yticks()` |

# %% [markdown]
# `plot`:
#
# `plot(x, y)        # plot x and y using default line style and color`
#
# `plot(x, y, 'bo')  # plot x and y using blue circle markers` [matplotlib line markers](https://matplotlib.org/stable/api/markers_api.html)
#
# ```
# plot(x, y, color='green', marker='o', linestyle='dashed', linewidth=2, markersize=12)
# ```
#
# * [matplotlib colors](https://matplotlib.org/stable/gallery/color/named_colors.html)
#
# * [matplotlib linestyles](https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html)

# %% [markdown]
# `plot` is used for linear plotting. You can pass the x and y data and it will plot them and connect between them. Or, you can pass one data and it will plot it against sequential data from 0 to the count of the data passed - 1.
#
# You can also pass some arguments to modify the plot regarding its style, its color, etc.
#
# * `marker`: the marker shape of the points plotted in the figure.
# * `linestyle`: the style of the lines connecting between the points.
# * `color`: the color of the plot

# %%
fig, ax = plt.subplots(2, 4, figsize=(20, 5))
ax[0, 0].plot(sin)
ax[0, 1].plot(range(1000), sin)
ax[0, 2].plot(np.linspace(-4, 4, 1000), sin)
ax[0, 3].plot(sin[::100], 'o') # set the plot to disconnected dots
ax[1, 0].plot(sin, c = 'r') # set the color of the plot to red
ax[1, 1].plot(sin, '--') # set the plot to dashed lines
ax[1, 2].plot(sin, lw = 3) # set the line width of the plot to 3 (bold)
ax[1, 3].plot(sin[::100], '--o')
plt.tight_layout() # makes plot and legend fit well with each other - not overlapping

# %% [markdown]
# `scatter`

# %% [markdown]
# `scatter` plots continous quantities where each data is represented as a single not-connected point.

# %% [markdown]
# `plt.scatter(x, y) # scatter plot between x, y using default settings`
#
# ```
# plt.scatter(x, y, z)
# # scatter plot between x, y and map the size of the marker using the corresponding value of z
# ```
#
# `plt.scatter(x, y, c = 'b') # scatter plot between x, y in blue markers`
#
# `plt.scatter(x, y, marker = 'v') # scatter plot between x, y in triangle-down-like markers` [Scatter Markers](https://matplotlib.org/stable/api/_as_gen/matplotlib.markers.MarkerStyle.html#matplotlib.markers.MarkerStyle)
#
#
# `plt.scatter(x, y, cmap = ""`

# %%
x = np.random.uniform(size = 50)
y = x + np.random.normal(0, 0.1, size = 50)

fig, ax = plt.subplots(2, 2, figsize=(7, 7), subplot_kw = {'xticks': (), 'yticks': ()})

ax[0, 0].scatter(x, y)
ax[0, 0].set_title('scatter')

ax[0, 1].plot(x, y, 'o')
ax[0, 1].set_title('plot')

ax[1, 0].scatter(x, y, c = x - y, cmap = 'bwr', edgecolor = 'k')
ax[1, 1].scatter(x, y, c = x - y, cmap = 'bwr', edgecolor = 'k', s = np.abs(np.random.normal(scale = 20, size = 50)))

plt.tight_layout()

# %% [markdown]
# `hist`

# %% [markdown]
# `hist` allows us to draw a histogram of continuos data

# %% [markdown]
# write the docs of `hist` `bins`

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 7))

ax[0].hist(np.random.normal(size=1000)) # default number of bins is 10
ax[1].hist(np.random.normal(size=1000), bins=100, color = 'y')
ax[2].hist(np.random.normal(size=1000), bins='auto', color = 'r'); #

# %% [markdown]
# `bar`

# %% [markdown]
# `bar` allows us to plot a bar plot for categorial data.
# `barh` allows to plot the bar plot in horizontal direction.

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.bar(x, y)
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(1, 2, 2)
plt.barh(x, y, color ='r')
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# **heatmaps**

# %% [markdown]
# We can use `imshow` to plot heatmaps.

# %%
fig, ax = plt.subplots(2, 2, figsize = (15, 15))

arr = np.random.normal(size = (10, 10))

im1 = ax[0, 0].imshow(arr) # we will use im1 for the color bar
im2 = ax[0, 1].imshow(arr, interpolation = 'bilinear')
im3 = ax[1, 0].imshow(arr, cmap = 'gray')
im4 = ax[1, 1].imshow(arr, cmap = 'bwr', vmin = -1.5, vmax = 1.5)


plt.colorbar(im1, ax = ax[0, 0]) # build a color bar and assign it to the axes of ax[0, 0]
plt.colorbar(im2, ax = ax[0, 1])
plt.colorbar(im3, ax = ax[1, 0])
plt.colorbar(im4, ax = ax[1, 1])

# %% [markdown]
# what are the best colormaps for the heatmaps ?

# %% [markdown]
# `hexbin`

# %% [markdown]
# `hexbin` is useful for plotting overlapping data where the color of each point represent the number of data points overlapping at that position.

# %%
x = np.random.normal(size=50000)
y = (x * 3 + np.random.normal(size=50000)) * 5
 

plt.figure(figsize=(10, 10))
plt.hexbin(x, y)
plt.colorbar()
plt.show()

# %% [markdown]
# `twinx`, `twiny`

# %% [markdown]
# If you tried to run the next code

# %%
plt.figure(figsize=(10, 10))

x1 = np.arange(0, 11)
y1 = x1 + np.random.normal(size = 11)
y2 = x1 + np.random.normal(size = 11) + 100

plt.plot(x1, y1)
plt.plot(x1, y2)

# %% [markdown]
# Both `y1` and `y2` have very different ranges. If you want to study the correlation between quantities that vary in their ranges with fixed third quantity, it would be helpful to use `twinx` (or `twiny` but `twinx` is more common)

# %%
x1 = np.arange(0, 11)
y1 = x1 + np.random.normal(size = 11)
y2 = x1 + np.random.normal(size = 11) + 10 ** 9

fig = plt.figure(figsize=(10, 10))

ax1 = fig.add_subplot(111) # get the current axes
ax1.plot(x1, y1, label="y1") # use label for legend
ax1.set_ylabel('y1')

ax2 = ax1.twinx()
ax2.plot(x1, y2, c = 'r', label="y2")
ax2.set_ylabel('y2')

fig.legend(loc="upper left", bbox_to_anchor=(0, 1), bbox_transform=ax1.transAxes) # to show the legend in twinx figure

# %% [markdown]
# 3D plotting

# %% [markdown]
# We can plot in 3d by adding this line.
#
# ```python
# from mpl_toolkits.mplot3d import Axes3D
# ```

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection = '3d')

x = np.arange(100)
y = np.random.random(100)
z = np.random.random(100)

ax.set_title('3D Projection')
ax.plot(x, y, z, lw = 2.5);

# %% [markdown]
# 3D Scattering

# %%
from sklearn.datasets import load_iris

iris = load_iris()
x, y = iris.data, iris.target

fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')

# for loop to add label, legend
for i in range(3):
    ax.scatter(x[y==i, 1], x[y==i, 2], x[y==i, 3], label = i)

ax.legend(loc='upper left')

# %% [markdown]
# `seaborn`

# %% [markdown]
# The following is a quick tutorial on how to use `seaborn` to generate popular kinds of plots. `seaborn` is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# Other References:
# 1. [User guide and tuorial - seabron](https://seaborn.pydata.org/tutorial.html)
# 2. [Python Seaborn Tutorial - GeeksForGeeks](https://www.geeksforgeeks.org/python-seaborn-tutorial/)
# 3. [The Ultimate Python Seaborn Tutorial: Gotta Catch ‘Em All](https://elitedatascience.com/python-seaborn-tutorial)

# %% [markdown]
# `seaborn`

# %% [markdown]
# `seaborn` is a hig-level data visualization library made based on top of `matplotlib` to make it easy to create the most common types of plots using few lines of code. It works very well with `pandas.DataFrame` objects.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# `relplot`

# %% [markdown]
# `relplot` is a function of the `seaborn` library that allows us to plot relational plots bewteen quantative variables. These relational plots include scatter plot and line plot with different customizations to each type can be set inside `relplot`.

# %%
student_data = pd.read_csv("assets/student-alcohol-consumption.csv")
student_data.head()
# Out:
#    Unnamed: 0 school sex  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0           0     GP   F   18     GT3       A     4     4           2
# 1           1     GP   F   17     GT3       T     1     1           1
# 2           2     GP   F   15     LE3       T     1     1           1
# 3           3     GP   F   15     GT3       T     4     2           1
# 4           4     GP   F   16     GT3       T     3     3           1
#
#    failures  ... goout Dalc Walc health absences  G1  G2  G3  location  \
# 0         0  ...     4    1    1      3        6   5   6   6     Urban
# 1         0  ...     3    1    1      3        4   5   5   6     Urban
# 2         3  ...     2    2    3      3       10   7   8  10     Urban
# 3         0  ...     2    1    1      5        2  15  14  15     Urban
# 4         0  ...     2    1    2      5        4   6  10  10     Urban
#
#       study_time
# 0   2 to 5 hours
# 1   2 to 5 hours
# 2   2 to 5 hours
# 3  5 to 10 hours
# 4   2 to 5 hours
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# ```python
# sns.relplot(
#     data = data, # the pandas dataframe
#     x = "xaxis", # a string represent the column of the data to be plotted on the x axis
#     y = "yaxis", # a string represent the column of the data to be plotted on the y axis
#     kind = "scatter", # a string represent the type of the relational plot
# )
# ```

# %%
sns.relplot(
    data = student_data,
    x = "absences",
    y = "G3",
    kind = "scatter"
)

# %% [markdown]
# We can subclass the data based on other categorial column using `hue` keyword.

# %%
sns.relplot(
    data = student_data,
    x = "absences",
    y = "G3",
    hue = "study_time",
    kind = "scatter"
)

# %% [markdown]
# We can also make separate the hue classes each in its own subplot instead of putting all of them together in a single plot. We can use the `col` or `row` keyword with `col_wrap` or `row_wrap` to define a max number of subplots per column or row.

# %%
sns.relplot(
    data = student_data,
    x = "absences",
    y = "G3",
    col = "study_time",
    col_wrap = 2,
    col_order = ["<2 hours", "2 to 5 hours", "5 to 10 hours", ">10 hours"],
    kind = "scatter"
)

# %% [markdown]
# We can create a 2-factor subplots, factor by columns and factor by rows.

# %%
sns.relplot(
    data = student_data,
    x = "G1",
    y = "G3",
    kind = "scatter",
    col = "schoolsup",
    col_order = ["yes", "no"],
    row = "famsup",
    row_order = ["yes", "no"]
)

# %% [markdown]
# We can use a continous (or ordinal) variable as the size of the markers by providing the column name in the `size` keyword.

# %%
mpg = pd.read_csv("assets/mpg.csv")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.relplot(
    data = mpg,
    x = "horsepower",
    y = "mpg",
    kind = "scatter",
    size = "cylinders"    
)

# %% [markdown]
# We can also use `cylinders` gradient as the hue color of the markers.

# %%
sns.relplot(
    data = mpg,
    x = "horsepower",
    y = "mpg",
    kind = "scatter",
    size = "cylinders",
    hue = "cylinders"  
)

# %% [markdown]
# For nominal categorial variable, it's preferred to use the marker shape and descriminative color to differntiate between the different classes.

# %%
sns.relplot(
    data = mpg,
    x = "acceleration",
    y = "mpg",
    kind = "scatter",
    style = "origin",
    hue = "origin"  
)

# %% [markdown]
# ### Line plot

# %% [markdown]
# We will still use `relplot` but we will change `kind` keyword argument to be `"line"` instead of `"scatter"`.

# %%
sns.relplot(
    data = mpg,
    kind = "line",
    x = "model_year",
    y = "mpg"
)

# %% [markdown]
# The generated figure is a line plot. The solid blue line is the mean of the mpg for each model year. Where by default, seaborn generates a 95% confidence interval with the shaded blue, assuming the data is normally random sample.

# %% [markdown]
# We can customize the line plot as following:

# %%
sns.relplot(
    data = mpg,
    kind = "line",
    x = "model_year",
    y = "horsepower",
    style = "origin",
    hue = "origin"
)

# %% [markdown]
# We can change the confidence interval interpretation to be the standard deviation of the values for each x-axis value through the `ci` keyword argument.

# %%
sns.relplot(
    data = mpg,
    kind = "line",
    x = "model_year",
    y = "horsepower",
    style = "origin",
    hue = "origin",
    ci = "sd" # stands for standard deviation
)

# %% [markdown]
# Or remove it and keep the mean only.

# %%
sns.relplot(
    data = mpg,
    kind = "line",
    x = "model_year",
    y = "horsepower",
    style = "origin",
    hue = "origin",
    ci = None # stands for standard deviation
)

# %% [markdown]
# We can show the markers of the points using `markers` keyword argument and keep the lines solid not dashed using `dashes` keyword argument.

# %%
sns.relplot(
    data = mpg,
    kind = "line",
    x = "model_year",
    y = "horsepower",
    style = "origin",
    hue = "origin",
    ci = None,
    dashes = False,  # to make all lines solid
    markers = True,  # to show the markers 
)

# %% [markdown]
# `catplot`

# %% [markdown]
# `catplot` is used for plots including a categorical variable. It includes count plots and bar plots.

# %%
survey_data = pd.read_csv("assets/young-people-survey-responses.csv")

survey_data.head()
# Out:
#    Unnamed: 0  Music  Techno  Movies  History  Mathematics  Pets  Spiders  \
# 0           0    5.0     1.0     5.0      1.0          3.0   4.0      1.0
# 1           1    4.0     1.0     5.0      1.0          5.0   5.0      1.0
# 2           2    5.0     1.0     5.0      1.0          5.0   5.0      1.0
# 3           3    5.0     2.0     5.0      4.0          4.0   1.0      5.0
# 4           4    5.0     2.0     5.0      3.0          2.0   1.0      1.0
#
#    Loneliness  Parents' advice   Internet usage  Finances   Age  Siblings  \
# 0         3.0              4.0  few hours a day       3.0  20.0       1.0
# 1         2.0              2.0  few hours a day       3.0  19.0       2.0
# 2         5.0              3.0  few hours a day       2.0  20.0       2.0
# 3         5.0              2.0  most of the day       2.0  22.0       1.0
# 4         3.0              3.0  few hours a day       4.0  20.0       1.0
#
#    Gender Village - town
# 0  female        village
# 1  female           city
# 2  female           city
# 3  female           city
# 4  female        village

# %% [markdown]
# ### Count plots

# %% [markdown]
# Plots used to show the number of observations of classes of a categorial variable.

# %%
sns.catplot(
    data = survey_data,
    x = "Internet usage",
    kind = "count"
)

# %% [markdown]
# We can make the bars appear horizontally instead of the default vertical view by just naming the categorial column in the `y` keyword argument instead of `x`.

# %%
sns.catplot(
    data = survey_data,
    y = "Internet usage",
    kind = "count"
)

# %% [markdown]
# We can also separate the subplots based on another cateogiral variable using either `col` or `row` keyword arguments.

# %%
sns.catplot(
    data = survey_data,
    y = "Internet usage",
    kind = "count",
    col = "Gender"
)

# %% [markdown]
# ### Bar plot

# %% [markdown]
# When we use bar plot with a categorial variable vs a continuous variable, it shows the mean of the continuous variable for each class in the categorical variable.

# %%
sns.catplot(
    data = survey_data,
    x = "Gender",
    y = "Mathematics",
    kind = "bar"
)

# %% [markdown]
# We can specify the order of the classes' bars in the bar (or count) plot using `order` keyword argument.

# %%
sns.catplot(
    data = student_data,
    x = "study_time",
    y = "G3",
    kind = "bar",
    order = ["<2 hours", "2 to 5 hours", "5 to 10 hours", ">10 hours"]
)

# %% [markdown]
# The black lines in the top of the bar (like in `relplot`) represent (by default) the confidence intervals of the continuous variable for each class of the categorical variable. We can modify it (like `relplot`) using the `ci` keyword argument.

# %%
sns.catplot(
    data = student_data,
    x = "study_time",
    y = "G3",
    kind = "bar",
    order = ["<2 hours", "2 to 5 hours", "5 to 10 hours", ">10 hours"],
    ci = None
)

# %% [markdown]
# We can another categorial variable in our data visualization using `hue`.

# %%
sns.catplot(
    data = student_data,
    x = "study_time",
    y = "G3",
    kind = "bar",
    order = ["<2 hours", "2 to 5 hours", "5 to 10 hours", ">10 hours"],
    ci = None,
    hue = "school"
)

# %% [markdown]
# ### Box plot

# %% [markdown]
# A box plot shows the distribution of a quantitative data for each class of the categorial variable. The box itself shows the 25th and 75th percentiles. The line in the middle of the box represents the median. The whiskers represent the remaining of the distribution and the floating circles represent the outliers.

# %% [markdown]
# We create the box plot by specifiying the `kind` keyword argument in `catplot` to `"box"`.

# %%
sns.catplot(
    data = student_data,
    x = "study_time",
    y = "G3",
    kind = "box",
    order = ["<2 hours", "2 to 5 hours", "5 to 10 hours", ">10 hours"]
)

# %% [markdown]
# We can also customize the box plot to:
#
# * add subgroups of another categorial variable using color by `hue`.
# * Remove the outliers (or modify them) using the `sym` argument. If we passed an empty string `""`, no outliers will be shown.
# * Modify the location of the whiskers using `whis` keyword either:
#   * passing a float number (e.g., `2.0`) and that will be the factor multiplied by the IQR (Q3 - Q1). Default is 1.5*IQR.
#   * passing a list of 2 numbers (e.g., `[5, 95]`) and the whiskers will be at those percentiles.

# %%
sns.catplot(
    data = student_data,
    x = "internet",
    y = "G3",
    kind = "box",
    hue = "location",
    sym = "",
    whis = [10, 95]
)

# %% [markdown]
# ### Point plots

# %% [markdown]
# Point plot show the mean of a quantitative variable for each group of a categorical variable as a **point**. Vertical lines show 95% confidence intervals.

# %%
sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point"
)

# %% [markdown]
# We can add "caps" to the end of the vertical lines using `capsize` keyword argument. If we set `capsize = 0.2`, it will draw caps (horizontal lines) to 20% of the distance between every 2 classes on the x-axis.

# %%
sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point",
    capsize = 0.2
)

# %% [markdown]
# We can remove the lines connecting the points, we can do this by setting `join` to `False`.

# %%
sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point",
    join = False
)

# %% [markdown]
# We can remove the vertical lines representing the confidence intervals (or change them) by setting `ci` to `None`.

# %%
sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point",
    ci = None
)

# %% [markdown]
# We can as usual add another categorial variable as a hue.

# %%
sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point",
    ci = None,
    hue = "school"
)

# %% [markdown]
# And we can change the estimator that points represent. By default, it's the mean of the quantitative variable for each class of the categorical variable, but, you can set a function that you want to use instead of mean. For example, the median from `np.median` by setting the `estimator` keyword argument.

# %%
sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point",
    ci = None,
    hue = "school",
    estimator= np.median
)

# %% [markdown]
# ### Customizing the figure of the plots

# %%
sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point",
    hue = "school"
)

# %%
sns.set_style("whitegrid")

sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point",
    hue = "school"
)

# %%
sns.set_style("white")

sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point",
    hue = "school"
)

# %%
sns.set_style("dark")

sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point",
    hue = "school"
)

# %%
sns.set_style("darkgrid")

sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point",
    hue = "school"
)

# %% [markdown]
# ### Changing the palette

# %% [markdown]
# #### Default Palette

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %% [markdown]
# #### Diverging Palettes

# %%
sns.color_palette("RdBu")
# Out:
# [(0.7561707035755478, 0.21038062283737025, 0.22352941176470587),
#  (0.940715109573241, 0.6099192618223759, 0.4812764321414839),
#  (0.9856978085351787, 0.8889657823913879, 0.8320645905420992),
#  (0.8605151864667436, 0.9174163783160324, 0.9487120338331411),
#  (0.530026912725875, 0.7456362937331797, 0.8560553633217994),
#  (0.1843137254901961, 0.47266435986159167, 0.7116493656286044)]

# %%
sns.color_palette("PRGn")
# Out:
# [(0.5192618223760093, 0.27773933102652826, 0.578316032295271),
#  (0.7387158785082659, 0.6185313341022682, 0.7923875432525951),
#  (0.9231064975009612, 0.8690503652441369, 0.9259515570934256),
#  (0.8832756632064591, 0.9487120338331411, 0.8662053056516725),
#  (0.6100730488273743, 0.8346020761245676, 0.593540945790081),
#  (0.20761245674740486, 0.5577854671280277, 0.28350634371395617)]

# %%
sns.color_palette("RdBu_r")
# Out:
# [(0.18431372549019615, 0.4726643598615917, 0.7116493656286045),
#  (0.5300269127258748, 0.7456362937331797, 0.8560553633217993),
#  (0.8605151864667436, 0.9174163783160324, 0.9487120338331411),
#  (0.9856978085351789, 0.8889657823913879, 0.8320645905420991),
#  (0.9407151095732411, 0.609919261822376, 0.481276432141484),
#  (0.7561707035755478, 0.21038062283737025, 0.22352941176470587)]

# %%
sns.color_palette("PRGn_r")
# Out:
# [(0.20761245674740494, 0.5577854671280278, 0.2835063437139562),
#  (0.6100730488273742, 0.8346020761245676, 0.5935409457900809),
#  (0.8832756632064591, 0.9487120338331411, 0.8662053056516725),
#  (0.9231064975009612, 0.8690503652441369, 0.9259515570934256),
#  (0.738715878508266, 0.6185313341022683, 0.7923875432525952),
#  (0.5192618223760093, 0.27773933102652826, 0.578316032295271)]

# %% [markdown]
# #### Sequential Palettes

# %%
sns.color_palette("Greys")
# Out:
# [(0.9295040369088812, 0.9295040369088812, 0.9295040369088812),
#  (0.819115724721261, 0.819115724721261, 0.819115724721261),
#  (0.6770011534025375, 0.6770011534025375, 0.6770011534025375),
#  (0.5085736255286428, 0.5085736255286428, 0.5085736255286428),
#  (0.35912341407151094, 0.35912341407151094, 0.35912341407151094),
#  (0.1679354094579008, 0.1679354094579008, 0.1679354094579008)]

# %%
sns.color_palette("Blues")
# Out:
# [(0.8584083044982699, 0.9134486735870818, 0.9645674740484429),
#  (0.7309496347558632, 0.8394771241830065, 0.9213225682429834),
#  (0.5356862745098039, 0.746082276047674, 0.8642522106881968),
#  (0.32628988850442137, 0.6186236063052672, 0.802798923490965),
#  (0.16696655132641292, 0.48069204152249134, 0.7291503267973857),
#  (0.044059976931949255, 0.3338869665513264, 0.6244521337946944)]

# %%
sns.color_palette("PuRd")
# Out:
# [(0.896239907727797, 0.8620530565167243, 0.9265974625144175),
#  (0.8188542868127644, 0.6833833141099577, 0.833279507881584),
#  (0.8244367550941946, 0.5030526720492119, 0.7425451749327182),
#  (0.892718185313341, 0.25951557093425603, 0.6037062668204536),
#  (0.8362937331795464, 0.09676278354479047, 0.3964321414840446),
#  (0.6234832756632065, 0.009134948096885809, 0.2723875432525952)]

# %%
sns.color_palette("GnBu")
# Out:
# [(0.8682814302191465, 0.9488811995386389, 0.8476585928489042),
#  (0.7590311418685122, 0.9056362937331796, 0.7543406382160708),
#  (0.5847750865051903, 0.8386928104575164, 0.7344867358708189),
#  (0.37993079584775086, 0.7430988081507113, 0.8027681660899654),
#  (0.2084582852748943, 0.5934025374855825, 0.7689965397923876),
#  (0.04913494809688582, 0.4261130334486736, 0.6836447520184545)]

# %% [markdown]
# #### Custom Palettes

# %%
custom_palette = ["red", "green", "orange", "blue", "yellow", "purple"]
sns.color_palette(custom_palette)
# Out:
# [(1.0, 0.0, 0.0),
#  (0.0, 0.5019607843137255, 0.0),
#  (1.0, 0.6470588235294118, 0.0),
#  (0.0, 0.0, 1.0),
#  (1.0, 1.0, 0.0),
#  (0.5019607843137255, 0.0, 0.5019607843137255)]

# %% [markdown]
# ### Changing the scale

# %%
sns.set_context("paper") # default

sns.set_style("ticks")

sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point",
    hue = "school"
)

# %%
sns.set_context("poster")

sns.set_style("ticks")

sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point",
    hue = "school"
)

# %%
sns.set_context("talk")

sns.set_style("ticks")

sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point",
    hue = "school"
)

# %%
sns.set_context("notebook")

sns.set_style("ticks")

sns.catplot(
    data = student_data,
    x = "famrel",
    y = "absences",
    kind = "point",
    hue = "school"
)

# %% [markdown]
# ### Add title

# %% [markdown]
# We can add a title to our seaborn plot by accessing the figure member of the plot object. The type of the plot is `<class 'seaborn.axisgrid.FacetGrid'>` which has a `fig` member that has the method `suptitle` that adds the title.

# %%
g = sns.relplot(
    data = mpg,
    x = "weight",
    y = "horsepower",
    kind = "scatter"
)
print("Type of the plot is {}".format(type(g)))
g.fig.suptitle("Car Weight vs Horspower")
# Out:
# Type of the plot is <class 'seaborn.axisgrid.FacetGrid'>
# Text(0.5, 0.98, 'Car Weight vs Horspower')

# %% [markdown]
# We can make the title higher by setting the `y` argument to a number higher than `1` which is the default. Setting it to `1.03` will make the title higer by 3%.

# %%
g = sns.relplot(
    data = mpg,
    x = "weight",
    y = "horsepower",
    kind = "scatter"
)

g.fig.suptitle("Car Weight vs Horspower", y = 1.03)
# Out:
# Text(0.5, 1.03, 'Car Weight vs Horspower')

# %% [markdown]
# ### Setting x-label and y-label

# %% [markdown]
# We can set the x-label and y-label through the `set` method of the `FacetGrid` object by setting `xlabel` and `ylabel` to the new desired labels.

# %%
g = sns.relplot(
    data = mpg,
    x = "weight",
    y = "horsepower",
    kind = "scatter"
)

g.fig.suptitle("Car Weight vs Horspower", y = 1.03)

g.set(xlabel = "Weight (kg)", ylabel = "Horspower (horse)")
